# %% [markdown]
# <a href="https://colab.research.google.com/github/AnannyyaC/datasciencecoursera/blob/main/CDD_ML_Part_1_bioactivity_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Discovery
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# ...
#      |████████████████████████████████| 55 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for clostridium botulinum**

# %%
# Target search for clostridium botulinum
target = new_client.target
target_query = target.search('Clostridium botulinum')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0                                                  []
# 1                                                  []
# 2   [{'xref_id': 'P10845', 'xref_name': None, 'xre...
# 3   [{'xref_id': 'A5HZZ9', 'xref_name': None, 'xre...
# 4   [{'xref_id': 'P10844', 'xref_name': None, 'xre...
# 5                                                  []
# 6                                                  []
# 7   [{'xref_id': 'P60763', 'xref_name': None, 'xre...
# 8   [{'xref_id': 'P63001', 'xref_name': None, 'xre...
# 9   [{'xref_id': 'P15153', 'xref_name': None, 'xre...
# 10                                                 []
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14                                                 []
# 15                                                 []
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Botulinum neurotoxin type A* (third entry)**

# %% [markdown]
# We will assign the third entry (which corresponds to the target protein, *Botulinum neurotoxin type A*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[2]
selected_target
# Out:
# 'CHEMBL5192'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *clostridium botulinum neurotoxin type A * (CHEMBL5192) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id  \
# 0               None      2146977
# 1               None      2146978
# 2               None      2146979
# 3               None      2146980
# 4               None      2146981
# ..               ...          ...
# 507             None     22405028
# 508             None     22405032
# 509             None     22405090
# 510             None     22892264
# 511             None     22892265
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL925835
# 1                                                   []    CHEMBL925835
# 2                                                   []    CHEMBL925835
# 3                                                   []    CHEMBL925835
# 4                                                   []    CHEMBL925835
# ..                                                 ...             ...
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_new.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data1"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data1’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data1"
# Out:
# cp: cannot stat 'bioactivity_data.csv': No such file or directory

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data1"
# Out:
# total 0

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data_new.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# head: cannot open 'bioactivity_data.csv' for reading: No such file or directory

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     activity_comment  activity_id  \
# 0               None      2146977
# 1               None      2146978
# 2               None      2146979
# 3               None      2146980
# 4               None      2146981
# ..               ...          ...
# 507             None     22405028
# 508             None     22405032
# 509             None     22405090
# 510             None     22892264
# 511             None     22892265
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL925835
# 1                                                   []    CHEMBL925835
# 2                                                   []    CHEMBL925835
# 3                                                   []    CHEMBL925835
# 4                                                   []    CHEMBL925835
# ..                                                 ...             ...
# ...

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %%
mol_cid

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %%
##"Alternative method"
selection = ["molecule_chembl_id","canonical_smiles","standard_value"]
df3 = df2[selection]

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL406178  COc1ccc(CCNC(=O)CN(CC(=O)N[C@H]2C[C@@H]2c2cccc...
# 1         CHEMBL261728  O=C(NCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(=...
# 2         CHEMBL438558  O=C(NCCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(...
# 3         CHEMBL259400  COC(=O)c1cc2c3c(ccc2[nH]1)N(C(=O)c1nc2ccc(NC(=...
# 4         CHEMBL405801  COc1cccc(CCNC(=O)CN(CC(=O)NC2CCCc3ccccc32)C(=O...
# ..                 ...                                                ...
# 507      CHEMBL4761825     CS(=O)(=O)SCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 508      CHEMBL4788170              CCCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 509       CHEMBL237370                         O=C(/C=C/c1ccc(Cl)cc1Cl)NO
# 510      CHEMBL4777863  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2cc3ccccc...
# 511      CHEMBL4742073  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2ccccc2Cl...
#
#     standard_value
# 0           7600.0
# 1          91200.0
# ...

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL406178  COc1ccc(CCNC(=O)CN(CC(=O)N[C@H]2C[C@@H]2c2cccc...
# 1         CHEMBL261728  O=C(NCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(=...
# 2         CHEMBL438558  O=C(NCCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(...
# 3         CHEMBL259400  COC(=O)c1cc2c3c(ccc2[nH]1)N(C(=O)c1nc2ccc(NC(=...
# 4         CHEMBL405801  COc1cccc(CCNC(=O)CN(CC(=O)NC2CCCc3ccccc32)C(=O...
# ..                 ...                                                ...
# 505      CHEMBL4761825     CS(=O)(=O)SCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 506      CHEMBL4788170              CCCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 507       CHEMBL237370                         O=C(/C=C/c1ccc(Cl)cc1Cl)NO
# 508      CHEMBL4777863  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2cc3ccccc...
# 509      CHEMBL4742073  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2ccccc2Cl...
#
#     bioactivity_class standard_value
# 0        intermediate         7600.0
# ...

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL406178  COc1ccc(CCNC(=O)CN(CC(=O)N[C@H]2C[C@@H]2c2cccc...
# 1         CHEMBL261728  O=C(NCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(=...
# 2         CHEMBL438558  O=C(NCCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(...
# 3         CHEMBL259400  COC(=O)c1cc2c3c(ccc2[nH]1)N(C(=O)c1nc2ccc(NC(=...
# 4         CHEMBL405801  COc1cccc(CCNC(=O)CN(CC(=O)NC2CCCc3ccccc32)C(=O...
# ..                 ...                                                ...
# 507      CHEMBL4761825     CS(=O)(=O)SCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 508      CHEMBL4788170              CCCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 509       CHEMBL237370                         O=C(/C=C/c1ccc(Cl)cc1Cl)NO
# 510      CHEMBL4777863  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2cc3ccccc...
# 511      CHEMBL4742073  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2ccccc2Cl...
#
#     standard_value
# 0           7600.0
# 1          91200.0
# ...

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL406178  COc1ccc(CCNC(=O)CN(CC(=O)N[C@H]2C[C@@H]2c2cccc...
# 1         CHEMBL261728  O=C(NCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(=...
# 2         CHEMBL438558  O=C(NCCc1ccccc1)[C@@H]1CN(C(=O)c2ccc(-c3ccc(C(...
# 3         CHEMBL259400  COC(=O)c1cc2c3c(ccc2[nH]1)N(C(=O)c1nc2ccc(NC(=...
# 4         CHEMBL405801  COc1cccc(CCNC(=O)CN(CC(=O)NC2CCCc3ccccc32)C(=O...
# ..                 ...                                                ...
# 507      CHEMBL4761825     CS(=O)(=O)SCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 508      CHEMBL4788170              CCCCCNC(=O)CC(CC(=O)NO)c1ccc(Cl)cc1Cl
# 509       CHEMBL237370                         O=C(/C=C/c1ccc(Cl)cc1Cl)NO
# 510      CHEMBL4777863  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2cc3ccccc...
# 511      CHEMBL4742073  CC[C@@H](C)[C@@H](NS(=O)(=O)c1cccc(-c2ccccc2Cl...
#
#     standard_value             0
# 0           7600.0  intermediate
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data_new.csv', index=False)

# %%
! ls -l
# Out:
# total 380
# -rw-r--r-- 1 root root 296148 Apr  3 11:58 bioactivity_data_new.csv
# -rw-r--r-- 1 root root  38009 Apr  3 12:08 bioactivity_preprocessed_data.csv
# -rw-r--r-- 1 root root  38009 Apr  3 12:09 bioactivity_preprocessed_data_new.csv
# drwx------ 5 root root   4096 Apr  3 11:58 gdrive
# drwxr-xr-x 1 root root   4096 Mar 23 14:22 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data_new.csv "/content/gdrive/My Drive/Colab Notebooks/data1"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data1"
# Out:
# bioactivity_preprocessed_data_new.csv

# %% [markdown]
# ---
